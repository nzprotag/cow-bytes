# %%
import os
import random
from PIL import Image
import torch
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision import models
import torch.nn as nn
import torch.optim as optim
from triplet_utils import *
from utils import *
from torch.utils.data import random_split
from triplet_utils import train_and_evaluate_triplet

# 2. Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# 3. Create the dataset and dataloader
folder_path = '../../data/BiteCount/salient_poses/'   # Adjust this path
dataset = SimpleTripletDataset(folder_path, transform)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
import torch.nn.functional as F

# Custom Triplet Loss without margin
def triplet_loss_no_margin(anchor, positive, negative):
    # Calculate the pairwise distances
    pos_dist = F.pairwise_distance(anchor, positive)
    neg_dist = F.pairwise_distance(anchor, negative)
    
    # Compute the triplet loss without a margin
    loss = torch.clamp(pos_dist - neg_dist, min=0.0)
    
    # Return the mean of the loss over the batch
    return loss.mean()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

# Function to show a batch of triplets
def show_triplet_images(dataloader, num_triplets=4):
    # Get a batch of data
    anchor_batch, positive_batch, negative_batch, _ = next(iter(dataloader))
    
    # Set up matplotlib subplots
    fig, axes = plt.subplots(num_triplets, 3, figsize=(10, 10))

    # Convert tensors to numpy arrays for visualization
    def convert_tensor_to_img(tensor):
        # Convert to numpy, [C, H, W] -> [H, W, C]
        image = tensor.numpy().transpose((1, 2, 0))  # Permute to [H, W, C]
        image = np.clip(image, 0, 1)  # Clip any out-of-bound values (if necessary)
        return image
    
    # Show num_triplets triplet images (anchor, positive, negative)
    for i in range(num_triplets):
        # No need to permute in the caller; it is done inside convert_tensor_to_img
        anchor_img = convert_tensor_to_img(anchor_batch[i])
        positive_img = convert_tensor_to_img(positive_batch[i])
        negative_img = convert_tensor_to_img(negative_batch[i])

        # Display anchor, positive, negative in a row
        axes[i, 0].imshow(anchor_img)
        axes[i, 0].set_title('Anchor')
        axes[i, 0].axis('off')

        axes[i, 1].imshow(positive_img)
        axes[i, 1].set_title('Positive')
        axes[i, 1].axis('off')

        axes[i, 2].imshow(negative_img)
        axes[i, 2].set_title('Negative')
        axes[i, 2].axis('off')

    # Adjust spacing between plots
    plt.tight_layout()
    plt.show()

# Example usage
show_triplet_images(dataloader, num_triplets=4)

# %%
def custom_collate(batch):
    # Unpack the batch
    anchors, positives, negatives, labels = zip(*batch)

    # Stack tensors to create batches
    anchors = torch.stack(anchors)
    positives = torch.stack(positives)
    negatives = torch.stack(negatives)

    # Convert labels to a tensor
    labels = torch.tensor(labels, dtype=torch.float32).unsqueeze(1)

    return anchors, positives, negatives, labels

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
import numpy as np

# TripletModel definition
class TripletModel(nn.Module):
    def __init__(self):
        super(TripletModel, self).__init__()
        self.base_model = models.resnet50(pretrained=True)
        self.base_model.fc = nn.Linear(self.base_model.fc.in_features, 128)  # Adjust output size for embedding

    def forward(self, x):
        # Get the embedding directly from the base model
        return self.base_model(x)  # Call the model with input x

class TripletClassifier(nn.Module):
    def __init__(self, triplet_head, output_size=1):
        super(TripletClassifier, self).__init__()
        self.triplet_head = triplet_head
        self.classifier = nn.Linear(self.triplet_head.base_model.fc.out_features, output_size)  # Binary classification (logits)

    def forward(self, x):
        embedding = self.triplet_head(x)  # Output of base model
        class_output = self.classifier(embedding)  # Output for classification
        return embedding, class_output
# Load data
data_dir = '../../data/BiteCount/salient_poses/'

# Define transformations for training set and validation set
train_transforms = transforms.Compose([
    transforms.Resize((224, 224)),  # Resizing to square input
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

val_transforms = transforms.Compose([
    transforms.Resize((224, 224)),  # Resizing to square input
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load dataset
train_dataset = TripletDataset(data_dir, transform=train_transforms)
dataset_size = len(train_dataset)
class_names = train_dataset.classes

# Cross-validation setup
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Hyperparameters
batch_size = 64
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
num_epochs = 50
patience = 5
alpha = 0.7

# Placeholder to store metrics across folds
val_accuracies = []
val_f1_scores = []
precisions = []
recalls = []
roc_aucs = []

# Perform 5-Fold Cross Validation
fold_idx = 1

np.random.seed(42)

for train_idx, val_idx in kf.split(np.arange(dataset_size)):
    print(f"Fold {fold_idx}")

    # Subset the data for training and validation
    train_subset = torch.utils.data.Subset(train_dataset, train_idx)
    val_subset = torch.utils.data.Subset(train_dataset, val_idx)

    # Create DataLoader for train and validation
    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, collate_fn=custom_collate)
    val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False, collate_fn=custom_collate)

    # Initialize TripletModel
    triplet_model = TripletModel()
    # triplet_model.load_state_dict(torch.load('./triplet_model.pth'))
    model = TripletClassifier(triplet_model)
    model = model.to(device)

    # Define loss functions and optimizer
    criterion_classification = nn.BCEWithLogitsLoss()  # Binary cross-entropy with logits for binary classification
    criterion_triplet = triplet_loss_no_margin 
    optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.8)

    # Training loop with early stopping
    best_val_accuracy = float('inf')
    best_val_f1 = 0

    patience_counter = 0

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for batch in train_loader:
            # Unpack the batch correctly
            anchor, positive, negative, labels = batch
            
            # Move the tensors to the appropriate device
            anchor = anchor.to(device)
            positive = positive.to(device)
            negative = negative.to(device)
            labels = labels.to(device)  # Ensure labels are tensors

            # Forward pass
            anchor_embedding, anchor_output = model(anchor)
            positive_embedding, positive_output = model(positive)
            negative_embedding, negative_output = model(negative)

            # Calculate losses
            classification_loss = criterion_classification(anchor_output, labels)
            triplet_loss = criterion_triplet(anchor_embedding, positive_embedding, negative_embedding)

            # Combine losses
            loss = alpha * classification_loss + (1-alpha) * triplet_loss
            running_loss += loss.item()

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        avg_loss = running_loss / len(train_loader)
        print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {avg_loss:.4f}")

        # Validation step
        model.eval()
        val_preds, val_labels = [], []
        val_loss = 0.0

        with torch.no_grad():
            for batch in val_loader:
                anchor, positive, negative, labels = batch
                
                anchor = anchor.to(device)
                positive = positive.to(device)
                negative = negative.to(device)
                labels = labels.to(device)

                anchor_embedding, anchor_output = model(anchor)
                positive_embedding, positive_output = model(positive)
                negative_embedding, negative_output = model(negative)

                # Compute validation loss
                classification_loss = criterion_classification(anchor_output, labels)
                triplet_loss = criterion_triplet(anchor_embedding, positive_embedding, negative_embedding)
                val_loss += (classification_loss + triplet_loss).item()

                val_preds.append(torch.sigmoid(anchor_output).cpu().numpy())
                val_labels.append(labels.cpu().numpy())

        avg_val_loss = val_loss / len(val_loader)
        val_preds = np.concatenate(val_preds)
        val_labels = np.concatenate(val_labels)

        # Calculate metrics
        val_acc = accuracy_score(val_labels, (val_preds > 0.5).astype(int))
        val_f1 = f1_score(val_labels, (val_preds > 0.5).astype(int))
        precision = precision_score(val_labels, (val_preds > 0.5).astype(int))
        recall = recall_score(val_labels, (val_preds > 0.5).astype(int))
        roc_auc = roc_auc_score(val_labels, val_preds)

        # Print validation metrics
        print(f"Validation Loss: {avg_val_loss:.4f}, Accuracy: {val_acc:.4f}, F1 Score: {val_f1:.4f}, "
              f"Precision: {precision:.4f}, Recall: {recall:.4f}, ROC AUC: {roc_auc:.4f}")

        # Early stopping logic
        if val_acc > best_val_accuracy or val_f1 > best_val_f1:
            best_val_loss = avg_val_loss
            best_val_accuracy = val_acc
            best_val_f1 = val_f1
            best_precision = precision
            best_recall = recall
            best_roc_auc = roc_auc
            patience_counter = 0
            # Save model state
            torch.save(model.state_dict(), f'tripet_{fold_idx}.pth')
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break

    # Store fold metrics
    val_accuracies.append(best_val_accuracy)
    val_f1_scores.append(best_val_f1)
    precisions.append(best_precision)
    recalls.append(best_recall)
    roc_aucs.append(best_roc_auc)

    fold_idx += 1

    

# Print out the results after cross-validation
print(f"Average Validation Accuracy: {np.mean(val_accuracies):.4f}")
print(f"Average F1 Score: {np.mean(val_f1_scores):.4f}")
print(f"Average Precision: {np.mean(precisions):.4f}")
print(f"Average Recall: {np.mean(recalls):.4f}")
print(f"Average ROC AUC: {np.mean(roc_aucs):.4f}")
# Out:
# Fold 1
# Epoch [1/50], Loss: 0.8865
# Validation Loss: 1.6865, Accuracy: 0.4250, F1 Score: 0.5741, Precision: 0.4189, Recall: 0.9118, ROC AUC: 0.4981
# Epoch [2/50], Loss: 0.6979
# Validation Loss: 1.2661, Accuracy: 0.4125, F1 Score: 0.5841, Precision: 0.4177, Recall: 0.9706, ROC AUC: 0.4763
# Epoch [3/50], Loss: 0.6520
# Validation Loss: 1.3670, Accuracy: 0.4000, F1 Score: 0.3143, Precision: 0.3056, Recall: 0.3235, ROC AUC: 0.3587
# Epoch [4/50], Loss: 0.5987
# Validation Loss: 1.1428, Accuracy: 0.3625, F1 Score: 0.5049, Precision: 0.3768, Recall: 0.7647, ROC AUC: 0.2986
# Epoch [5/50], Loss: 0.5801
# Validation Loss: 1.0289, Accuracy: 0.4625, F1 Score: 0.4267, Precision: 0.3902, Recall: 0.4706, ROC AUC: 0.3421
# Epoch [6/50], Loss: 0.5684
# Validation Loss: 0.9987, Accuracy: 0.4875, F1 Score: 0.5176, Precision: 0.4314, Recall: 0.6471, ROC AUC: 0.4540
# Epoch [7/50], Loss: 0.5526
# Validation Loss: 0.9170, Accuracy: 0.5125, F1 Score: 0.6286, Precision: 0.4648, Recall: 0.9706, ROC AUC: 0.5953
# Epoch [8/50], Loss: 0.5402
# Validation Loss: 0.9867, Accuracy: 0.4625, F1 Score: 0.5743, Precision: 0.4328, Recall: 0.8529, ROC AUC: 0.5697
# Epoch [9/50], Loss: 0.5300
# Validation Loss: 0.9813, Accuracy: 0.4875, F1 Score: 0.5941, Precision: 0.4478, Recall: 0.8824, ROC AUC: 0.5563
# Epoch [10/50], Loss: 0.5109
# Validation Loss: 0.8600, Accuracy: 0.6500, F1 Score: 0.6667, Precision: 0.5600, Recall: 0.8235, ROC AUC: 0.7340
# Epoch [11/50], Loss: 0.5195
# Validation Loss: 0.8776, Accuracy: 0.5875, F1 Score: 0.6024, Precision: 0.5102, Recall: 0.7353, ROC AUC: 0.6784
# Epoch [12/50], Loss: 0.4626
# Validation Loss: 0.7771, Accuracy: 0.6000, F1 Score: 0.6000, Precision: 0.5217, Recall: 0.7059, ROC AUC: 0.7577
# Epoch [13/50], Loss: 0.4501
# Validation Loss: 0.8039, Accuracy: 0.6125, F1 Score: 0.6517, Precision: 0.5273, Recall: 0.8529, ROC AUC: 0.7705
# Epoch [14/50], Loss: 0.4255
# Validation Loss: 0.8031, Accuracy: 0.6250, F1 Score: 0.6154, Precision: 0.5455, Recall: 0.7059, ROC AUC: 0.7366
# Epoch [15/50], Loss: 0.3599
# Validation Loss: 0.7255, Accuracy: 0.7125, F1 Score: 0.7160, Precision: 0.6170, Recall: 0.8529, ROC AUC: 0.8453
# Epoch [16/50], Loss: 0.3512
# Validation Loss: 0.7497, Accuracy: 0.7125, F1 Score: 0.7356, Precision: 0.6038, Recall: 0.9412, ROC AUC: 0.8440
# Epoch [17/50], Loss: 0.3407
# Validation Loss: 0.7696, Accuracy: 0.7125, F1 Score: 0.7089, Precision: 0.6222, Recall: 0.8235, ROC AUC: 0.8510
# Epoch [18/50], Loss: 0.3717
# Validation Loss: 0.7229, Accuracy: 0.7000, F1 Score: 0.7000, Precision: 0.6087, Recall: 0.8235, ROC AUC: 0.8683
# Epoch [19/50], Loss: 0.2818
# Validation Loss: 0.6013, Accuracy: 0.8000, F1 Score: 0.7647, Precision: 0.7647, Recall: 0.7647, ROC AUC: 0.9028
# Epoch [20/50], Loss: 0.2839
# Validation Loss: 0.6154, Accuracy: 0.8000, F1 Score: 0.7714, Precision: 0.7500, Recall: 0.7941, ROC AUC: 0.9066
# Epoch [21/50], Loss: 0.2451
# Validation Loss: 0.8504, Accuracy: 0.7875, F1 Score: 0.7606, Precision: 0.7297, Recall: 0.7941, ROC AUC: 0.8708
# Epoch [22/50], Loss: 0.2988
# Validation Loss: 0.8186, Accuracy: 0.8000, F1 Score: 0.7838, Precision: 0.7250, Recall: 0.8529, ROC AUC: 0.8913
# Epoch [23/50], Loss: 0.2619
# Validation Loss: 0.4946, Accuracy: 0.8000, F1 Score: 0.8000, Precision: 0.6957, Recall: 0.9412, ROC AUC: 0.9399
# Epoch [24/50], Loss: 0.2663
# Validation Loss: 0.6213, Accuracy: 0.8125, F1 Score: 0.8000, Precision: 0.7317, Recall: 0.8824, ROC AUC: 0.9054
# Epoch [25/50], Loss: 0.2684
# Validation Loss: 0.8654, Accuracy: 0.7875, F1 Score: 0.7733, Precision: 0.7073, Recall: 0.8529, ROC AUC: 0.8760
# Epoch [26/50], Loss: 0.2695
# Validation Loss: 0.4910, Accuracy: 0.8625, F1 Score: 0.8493, Precision: 0.7949, Recall: 0.9118, ROC AUC: 0.9341
# Epoch [27/50], Loss: 0.2084
# Validation Loss: 0.4494, Accuracy: 0.8375, F1 Score: 0.8267, Precision: 0.7561, Recall: 0.9118, ROC AUC: 0.9559
# Epoch [28/50], Loss: 0.2011
# Validation Loss: 0.5141, Accuracy: 0.8875, F1 Score: 0.8696, Precision: 0.8571, Recall: 0.8824, ROC AUC: 0.9591
# Epoch [29/50], Loss: 0.2327
# Validation Loss: 0.8771, Accuracy: 0.6875, F1 Score: 0.7191, Precision: 0.5818, Recall: 0.9412, ROC AUC: 0.9226
# Epoch [30/50], Loss: 0.2118
# Validation Loss: 0.6465, Accuracy: 0.7875, F1 Score: 0.7792, Precision: 0.6977, Recall: 0.8824, ROC AUC: 0.8887
# Epoch [31/50], Loss: 0.1737
# Validation Loss: 0.4829, Accuracy: 0.9125, F1 Score: 0.9014, Precision: 0.8649, Recall: 0.9412, ROC AUC: 0.9246
# Epoch [32/50], Loss: 0.1372
# Validation Loss: 0.8459, Accuracy: 0.7500, F1 Score: 0.7561, Precision: 0.6458, Recall: 0.9118, ROC AUC: 0.9118
# Epoch [33/50], Loss: 0.1350
# Validation Loss: 0.5131, Accuracy: 0.8625, F1 Score: 0.8493, Precision: 0.7949, Recall: 0.9118, ROC AUC: 0.9309
# Epoch [34/50], Loss: 0.1388
# Validation Loss: 0.5415, Accuracy: 0.8625, F1 Score: 0.8608, Precision: 0.7556, Recall: 1.0000, ROC AUC: 0.9623
# Epoch [35/50], Loss: 0.1431
# Validation Loss: 0.3844, Accuracy: 0.9000, F1 Score: 0.8788, Precision: 0.9062, Recall: 0.8529, ROC AUC: 0.9763
# Epoch [36/50], Loss: 0.1221
# Validation Loss: 0.5252, Accuracy: 0.8750, F1 Score: 0.8529, Precision: 0.8529, Recall: 0.8529, ROC AUC: 0.9450
# Early stopping triggered.
# Fold 2
# Epoch [1/50], Loss: 0.8781
# Validation Loss: 1.7175, Accuracy: 0.5000, F1 Score: 0.2000, Precision: 0.4545, Recall: 0.1282, ROC AUC: 0.5216
# Epoch [2/50], Loss: 0.7170
# Validation Loss: 1.4063, Accuracy: 0.4875, F1 Score: 0.4938, Precision: 0.4762, Recall: 0.5128, ROC AUC: 0.4722
# Epoch [3/50], Loss: 0.6428
# Validation Loss: 1.2718, Accuracy: 0.5000, F1 Score: 0.5918, Precision: 0.4915, Recall: 0.7436, ROC AUC: 0.4547
# Epoch [4/50], Loss: 0.6152
# Validation Loss: 1.1417, Accuracy: 0.4500, F1 Score: 0.2903, Precision: 0.3913, Recall: 0.2308, ROC AUC: 0.3727
# Epoch [5/50], Loss: 0.5889
# Validation Loss: 1.1496, Accuracy: 0.4625, F1 Score: 0.0000, Precision: 0.0000, Recall: 0.0000, ROC AUC: 0.3940
# Epoch [6/50], Loss: 0.5717
# Validation Loss: 0.9582, Accuracy: 0.4625, F1 Score: 0.6195, Precision: 0.4730, Recall: 0.8974, ROC AUC: 0.3902
# Epoch [7/50], Loss: 0.5713
# Validation Loss: 1.0931, Accuracy: 0.4375, F1 Score: 0.1509, Precision: 0.2857, Recall: 0.1026, ROC AUC: 0.3959
# Epoch [8/50], Loss: 0.5518
# Validation Loss: 0.9735, Accuracy: 0.5125, F1 Score: 0.2642, Precision: 0.5000, Recall: 0.1795, ROC AUC: 0.5472
# Epoch [9/50], Loss: 0.5285
# Validation Loss: 0.9867, Accuracy: 0.6000, F1 Score: 0.6098, Precision: 0.5814, Recall: 0.6410, ROC AUC: 0.6498
# Epoch [10/50], Loss: 0.5178
# Validation Loss: 1.0538, Accuracy: 0.6000, F1 Score: 0.5294, Precision: 0.6207, Recall: 0.4615, ROC AUC: 0.5704
# Epoch [11/50], Loss: 0.4991
# Validation Loss: 0.9540, Accuracy: 0.5625, F1 Score: 0.5679, Precision: 0.5476, Recall: 0.5897, ROC AUC: 0.5916
# Epoch [12/50], Loss: 0.5015
# Validation Loss: 1.0017, Accuracy: 0.5500, F1 Score: 0.4706, Precision: 0.5517, Recall: 0.4103, ROC AUC: 0.5572
# Epoch [13/50], Loss: 0.4814
# Validation Loss: 0.9622, Accuracy: 0.6250, F1 Score: 0.6341, Precision: 0.6047, Recall: 0.6667, ROC AUC: 0.6767
# Epoch [14/50], Loss: 0.4500
# Validation Loss: 0.8624, Accuracy: 0.6625, F1 Score: 0.6301, Precision: 0.6765, Recall: 0.5897, ROC AUC: 0.7523
# Epoch [15/50], Loss: 0.4338
# Validation Loss: 1.0964, Accuracy: 0.6125, F1 Score: 0.6076, Precision: 0.6000, Recall: 0.6154, ROC AUC: 0.6379
# Epoch [16/50], Loss: 0.3969
# Validation Loss: 1.1662, Accuracy: 0.6500, F1 Score: 0.6667, Precision: 0.6222, Recall: 0.7179, ROC AUC: 0.7417
# Epoch [17/50], Loss: 0.3750
# Validation Loss: 0.9471, Accuracy: 0.7250, F1 Score: 0.6944, Precision: 0.7576, Recall: 0.6410, ROC AUC: 0.8155
# Epoch [18/50], Loss: 0.3463
# Validation Loss: 0.9060, Accuracy: 0.7125, F1 Score: 0.7160, Precision: 0.6905, Recall: 0.7436, ROC AUC: 0.7974
# Epoch [19/50], Loss: 0.2977
# Validation Loss: 0.7774, Accuracy: 0.7750, F1 Score: 0.7568, Precision: 0.8000, Recall: 0.7179, ROC AUC: 0.8605
# Epoch [20/50], Loss: 0.3017
# Validation Loss: 0.9669, Accuracy: 0.7875, F1 Score: 0.7733, Precision: 0.8056, Recall: 0.7436, ROC AUC: 0.8743
# Epoch [21/50], Loss: 0.2856
# Validation Loss: 0.7909, Accuracy: 0.8125, F1 Score: 0.8101, Precision: 0.8000, Recall: 0.8205, ROC AUC: 0.8680
# Epoch [22/50], Loss: 0.3149
# Validation Loss: 0.7057, Accuracy: 0.7500, F1 Score: 0.7778, Precision: 0.6863, Recall: 0.8974, ROC AUC: 0.9056
# Epoch [23/50], Loss: 0.2556
# Validation Loss: 1.5077, Accuracy: 0.7375, F1 Score: 0.6866, Precision: 0.8214, Recall: 0.5897, ROC AUC: 0.8274
# Epoch [24/50], Loss: 0.2839
# Validation Loss: 0.8599, Accuracy: 0.7500, F1 Score: 0.7826, Precision: 0.6792, Recall: 0.9231, ROC AUC: 0.8168
# Epoch [25/50], Loss: 0.2962
# Validation Loss: 1.1432, Accuracy: 0.6500, F1 Score: 0.5484, Precision: 0.7391, Recall: 0.4359, ROC AUC: 0.7961
# Epoch [26/50], Loss: 0.2359
# Validation Loss: 1.0044, Accuracy: 0.7750, F1 Score: 0.7353, Precision: 0.8621, Recall: 0.6410, ROC AUC: 0.8806
# Early stopping triggered.
# Fold 3
# Epoch [1/50], Loss: 0.8911
# Validation Loss: 1.5617, Accuracy: 0.5190, F1 Score: 0.6200, Precision: 0.5345, Recall: 0.7381, ROC AUC: 0.4273
# Epoch [2/50], Loss: 0.7120
# Validation Loss: 1.3792, Accuracy: 0.4177, F1 Score: 0.2333, Precision: 0.3889, Recall: 0.1667, ROC AUC: 0.3571
# Epoch [3/50], Loss: 0.6477
# Validation Loss: 1.3296, Accuracy: 0.4051, F1 Score: 0.4198, Precision: 0.4359, Recall: 0.4048, ROC AUC: 0.3333
# Epoch [4/50], Loss: 0.6153
# Validation Loss: 1.1927, Accuracy: 0.4557, F1 Score: 0.0444, Precision: 0.3333, Recall: 0.0238, ROC AUC: 0.3501
# Epoch [5/50], Loss: 0.5873
# Validation Loss: 1.0200, Accuracy: 0.4684, F1 Score: 0.6250, Precision: 0.5000, Recall: 0.8333, ROC AUC: 0.3874
# Epoch [6/50], Loss: 0.5705
# Validation Loss: 0.9892, Accuracy: 0.4051, F1 Score: 0.1455, Precision: 0.3077, Recall: 0.0952, ROC AUC: 0.3842
# Epoch [7/50], Loss: 0.5742
# Validation Loss: 0.9610, Accuracy: 0.3924, F1 Score: 0.1111, Precision: 0.2500, Recall: 0.0714, ROC AUC: 0.4344
# Epoch [8/50], Loss: 0.5599
# Validation Loss: 0.9865, Accuracy: 0.4430, F1 Score: 0.3714, Precision: 0.4643, Recall: 0.3095, ROC AUC: 0.3990
# Epoch [9/50], Loss: 0.5384
# Validation Loss: 0.9582, Accuracy: 0.4304, F1 Score: 0.4000, Precision: 0.4545, Recall: 0.3571, ROC AUC: 0.4897
# Epoch [10/50], Loss: 0.5300
# Validation Loss: 0.9700, Accuracy: 0.5063, F1 Score: 0.4507, Precision: 0.5517, Recall: 0.3810, ROC AUC: 0.5225
# Epoch [11/50], Loss: 0.5264
# Validation Loss: 0.9179, Accuracy: 0.5570, F1 Score: 0.5679, Precision: 0.5897, Recall: 0.5476, ROC AUC: 0.5393
# Epoch [12/50], Loss: 0.5109
# Validation Loss: 1.0582, Accuracy: 0.5823, F1 Score: 0.4762, Precision: 0.7143, Recall: 0.3571, ROC AUC: 0.6190
# Epoch [13/50], Loss: 0.4960
# Validation Loss: 0.9273, Accuracy: 0.5190, F1 Score: 0.5682, Precision: 0.5435, Recall: 0.5952, ROC AUC: 0.5714
# Epoch [14/50], Loss: 0.4819
# Validation Loss: 0.8779, Accuracy: 0.5696, F1 Score: 0.5641, Precision: 0.6111, Recall: 0.5238, ROC AUC: 0.6165
# Epoch [15/50], Loss: 0.4724
# Validation Loss: 0.9619, Accuracy: 0.6203, F1 Score: 0.6154, Precision: 0.6667, Recall: 0.5714, ROC AUC: 0.6898
# Epoch [16/50], Loss: 0.4688
# Validation Loss: 0.9469, Accuracy: 0.6456, F1 Score: 0.6744, Precision: 0.6591, Recall: 0.6905, ROC AUC: 0.7169
# Epoch [17/50], Loss: 0.4320
# Validation Loss: 0.7290, Accuracy: 0.7468, F1 Score: 0.7872, Precision: 0.7115, Recall: 0.8810, ROC AUC: 0.8024
# Epoch [18/50], Loss: 0.4040
# Validation Loss: 0.9665, Accuracy: 0.6962, F1 Score: 0.6842, Precision: 0.7647, Recall: 0.6190, ROC AUC: 0.7523
# Epoch [19/50], Loss: 0.3748
# Validation Loss: 1.0490, Accuracy: 0.7089, F1 Score: 0.7089, Precision: 0.7568, Recall: 0.6667, ROC AUC: 0.7555
# Epoch [20/50], Loss: 0.3693
# Validation Loss: 0.9019, Accuracy: 0.7468, F1 Score: 0.7872, Precision: 0.7115, Recall: 0.8810, ROC AUC: 0.7761
# Epoch [21/50], Loss: 0.3388
# Validation Loss: 1.0069, Accuracy: 0.7595, F1 Score: 0.7765, Precision: 0.7674, Recall: 0.7857, ROC AUC: 0.8340
# Epoch [22/50], Loss: 0.2985
# Validation Loss: 1.0495, Accuracy: 0.6835, F1 Score: 0.7191, Precision: 0.6809, Recall: 0.7619, ROC AUC: 0.8005
# Epoch [23/50], Loss: 0.2735
# Validation Loss: 1.1102, Accuracy: 0.7342, F1 Score: 0.7586, Precision: 0.7333, Recall: 0.7857, ROC AUC: 0.8185
# Epoch [24/50], Loss: 0.2716
# Validation Loss: 1.0040, Accuracy: 0.7975, F1 Score: 0.8049, Precision: 0.8250, Recall: 0.7857, ROC AUC: 0.8919
# Epoch [25/50], Loss: 0.2854
# Validation Loss: 1.0286, Accuracy: 0.6962, F1 Score: 0.7391, Precision: 0.6800, Recall: 0.8095, ROC AUC: 0.8301
# Epoch [26/50], Loss: 0.3130
# Validation Loss: 0.7129, Accuracy: 0.8101, F1 Score: 0.8235, Precision: 0.8140, Recall: 0.8333, ROC AUC: 0.8964
# Epoch [27/50], Loss: 0.2781
# Validation Loss: 0.8129, Accuracy: 0.7975, F1 Score: 0.8222, Precision: 0.7708, Recall: 0.8810, ROC AUC: 0.8584
# Epoch [28/50], Loss: 0.2919
# Validation Loss: 1.1281, Accuracy: 0.7848, F1 Score: 0.7952, Precision: 0.8049, Recall: 0.7857, ROC AUC: 0.8797
# Epoch [29/50], Loss: 0.2254
# Validation Loss: 0.8261, Accuracy: 0.8228, F1 Score: 0.8293, Precision: 0.8500, Recall: 0.8095, ROC AUC: 0.9112
# Epoch [30/50], Loss: 0.1897
# Validation Loss: 0.9381, Accuracy: 0.7975, F1 Score: 0.8095, Precision: 0.8095, Recall: 0.8095, ROC AUC: 0.8803
# Epoch [31/50], Loss: 0.1913
# Validation Loss: 0.9547, Accuracy: 0.8101, F1 Score: 0.8276, Precision: 0.8000, Recall: 0.8571, ROC AUC: 0.9241
# Epoch [32/50], Loss: 0.2176
# Validation Loss: 0.8447, Accuracy: 0.7848, F1 Score: 0.8046, Precision: 0.7778, Recall: 0.8333, ROC AUC: 0.8790
# Epoch [33/50], Loss: 0.2265
# Validation Loss: 0.8312, Accuracy: 0.7848, F1 Score: 0.7848, Precision: 0.8378, Recall: 0.7381, ROC AUC: 0.9254
# Epoch [34/50], Loss: 0.1614
# Validation Loss: 0.7694, Accuracy: 0.7975, F1 Score: 0.8000, Precision: 0.8421, Recall: 0.7619, ROC AUC: 0.8784
# Early stopping triggered.
# Fold 4
# Epoch [1/50], Loss: 0.8883
# Validation Loss: 1.8044, Accuracy: 0.4684, F1 Score: 0.3226, Precision: 0.4762, Recall: 0.2439, ROC AUC: 0.4730
# Epoch [2/50], Loss: 0.7032
# Validation Loss: 1.3679, Accuracy: 0.4304, F1 Score: 0.3284, Precision: 0.4231, Recall: 0.2683, ROC AUC: 0.4544
# Epoch [3/50], Loss: 0.6478
# Validation Loss: 1.2851, Accuracy: 0.4051, F1 Score: 0.2985, Precision: 0.3846, Recall: 0.2439, ROC AUC: 0.3870
# Epoch [4/50], Loss: 0.5995
# Validation Loss: 1.1205, Accuracy: 0.4051, F1 Score: 0.4337, Precision: 0.4286, Recall: 0.4390, ROC AUC: 0.3524
# Epoch [5/50], Loss: 0.5859
# Validation Loss: 1.1613, Accuracy: 0.4304, F1 Score: 0.1818, Precision: 0.3571, Recall: 0.1220, ROC AUC: 0.3562
# Epoch [6/50], Loss: 0.5774
# Validation Loss: 1.0287, Accuracy: 0.4810, F1 Score: 0.5684, Precision: 0.5000, Recall: 0.6585, ROC AUC: 0.4114
# Epoch [7/50], Loss: 0.5670
# Validation Loss: 1.0651, Accuracy: 0.4557, F1 Score: 0.2456, Precision: 0.4375, Recall: 0.1707, ROC AUC: 0.2920
# Epoch [8/50], Loss: 0.5522
# Validation Loss: 0.9939, Accuracy: 0.4684, F1 Score: 0.5532, Precision: 0.4906, Recall: 0.6341, ROC AUC: 0.4089
# Epoch [9/50], Loss: 0.5339
# Validation Loss: 1.0810, Accuracy: 0.4684, F1 Score: 0.1250, Precision: 0.4286, Recall: 0.0732, ROC AUC: 0.4076
# Epoch [10/50], Loss: 0.5206
# Validation Loss: 0.9889, Accuracy: 0.4810, F1 Score: 0.5941, Precision: 0.5000, Recall: 0.7317, ROC AUC: 0.4929
# Epoch [11/50], Loss: 0.5102
# Validation Loss: 1.0115, Accuracy: 0.5316, F1 Score: 0.4932, Precision: 0.5625, Recall: 0.4390, ROC AUC: 0.5616
# Epoch [12/50], Loss: 0.4813
# Validation Loss: 0.9619, Accuracy: 0.5443, F1 Score: 0.6087, Precision: 0.5490, Recall: 0.6829, ROC AUC: 0.5950
# Epoch [13/50], Loss: 0.4757
# Validation Loss: 1.0209, Accuracy: 0.5823, F1 Score: 0.5352, Precision: 0.6333, Recall: 0.4634, ROC AUC: 0.6643
# Epoch [14/50], Loss: 0.4768
# Validation Loss: 0.9717, Accuracy: 0.5316, F1 Score: 0.5316, Precision: 0.5526, Recall: 0.5122, ROC AUC: 0.5693
# Epoch [15/50], Loss: 0.4481
# Validation Loss: 0.9748, Accuracy: 0.5823, F1 Score: 0.5352, Precision: 0.6333, Recall: 0.4634, ROC AUC: 0.6669
# Epoch [16/50], Loss: 0.4093
# Validation Loss: 1.0528, Accuracy: 0.6582, F1 Score: 0.6494, Precision: 0.6944, Recall: 0.6098, ROC AUC: 0.7298
# Epoch [17/50], Loss: 0.4091
# Validation Loss: 1.0622, Accuracy: 0.5696, F1 Score: 0.6136, Precision: 0.5745, Recall: 0.6585, ROC AUC: 0.6791
# Epoch [18/50], Loss: 0.3946
# Validation Loss: 1.1969, Accuracy: 0.6203, F1 Score: 0.6429, Precision: 0.6279, Recall: 0.6585, ROC AUC: 0.6791
# Epoch [19/50], Loss: 0.3256
# Validation Loss: 0.8788, Accuracy: 0.7468, F1 Score: 0.7436, Precision: 0.7838, Recall: 0.7073, ROC AUC: 0.8145
# Epoch [20/50], Loss: 0.3152
# Validation Loss: 0.9228, Accuracy: 0.7342, F1 Score: 0.7042, Precision: 0.8333, Recall: 0.6098, ROC AUC: 0.8421
# Epoch [21/50], Loss: 0.3004
# Validation Loss: 0.8058, Accuracy: 0.7975, F1 Score: 0.8182, Precision: 0.7660, Recall: 0.8780, ROC AUC: 0.8729
# Epoch [22/50], Loss: 0.2599
# Validation Loss: 0.6963, Accuracy: 0.7848, F1 Score: 0.7606, Precision: 0.9000, Recall: 0.6585, ROC AUC: 0.9114
# Epoch [23/50], Loss: 0.2471
# Validation Loss: 0.9612, Accuracy: 0.7975, F1 Score: 0.8182, Precision: 0.7660, Recall: 0.8780, ROC AUC: 0.8466
# Epoch [24/50], Loss: 0.2843
# Validation Loss: 0.6863, Accuracy: 0.8228, F1 Score: 0.8333, Precision: 0.8140, Recall: 0.8537, ROC AUC: 0.9018
# Epoch [25/50], Loss: 0.2832
# Validation Loss: 1.1237, Accuracy: 0.7975, F1 Score: 0.7949, Precision: 0.8378, Recall: 0.7561, ROC AUC: 0.8389
# Epoch [26/50], Loss: 0.2288
# Validation Loss: 0.8164, Accuracy: 0.8228, F1 Score: 0.8250, Precision: 0.8462, Recall: 0.8049, ROC AUC: 0.8890
# Epoch [27/50], Loss: 0.2257
# Validation Loss: 0.7017, Accuracy: 0.8101, F1 Score: 0.8052, Precision: 0.8611, Recall: 0.7561, ROC AUC: 0.9121
# Epoch [28/50], Loss: 0.2166
# Validation Loss: 0.6429, Accuracy: 0.7722, F1 Score: 0.8085, Precision: 0.7170, Recall: 0.9268, ROC AUC: 0.9056
# Epoch [29/50], Loss: 0.2672
# Validation Loss: 0.7555, Accuracy: 0.7848, F1 Score: 0.7901, Precision: 0.8000, Recall: 0.7805, ROC AUC: 0.8851
# Early stopping triggered.
# Fold 5
# Epoch [1/50], Loss: 0.8910
# Validation Loss: 1.6840, Accuracy: 0.4684, F1 Score: 0.4167, Precision: 0.5000, Recall: 0.3571, ROC AUC: 0.4395
# Epoch [2/50], Loss: 0.7185
# Validation Loss: 1.3434, Accuracy: 0.4177, F1 Score: 0.3947, Precision: 0.4412, Recall: 0.3571, ROC AUC: 0.4086
# Epoch [3/50], Loss: 0.6340
# Validation Loss: 1.2227, Accuracy: 0.4684, F1 Score: 0.2759, Precision: 0.5000, Recall: 0.1905, ROC AUC: 0.4891
# Epoch [4/50], Loss: 0.5988
# Validation Loss: 1.2479, Accuracy: 0.4557, F1 Score: 0.0000, Precision: 0.0000, Recall: 0.0000, ROC AUC: 0.2986
# Epoch [5/50], Loss: 0.5803
# Validation Loss: 1.1370, Accuracy: 0.5063, F1 Score: 0.4348, Precision: 0.5556, Recall: 0.3571, ROC AUC: 0.3893
# Epoch [6/50], Loss: 0.5636
# Validation Loss: 0.9793, Accuracy: 0.4177, F1 Score: 0.3611, Precision: 0.4333, Recall: 0.3095, ROC AUC: 0.4009
# Epoch [7/50], Loss: 0.5471
# Validation Loss: 1.0403, Accuracy: 0.5190, F1 Score: 0.3667, Precision: 0.6111, Recall: 0.2619, ROC AUC: 0.4961
# Epoch [8/50], Loss: 0.5431
# Validation Loss: 1.0252, Accuracy: 0.5443, F1 Score: 0.4706, Precision: 0.6154, Recall: 0.3810, ROC AUC: 0.4704
# Epoch [9/50], Loss: 0.5188
# Validation Loss: 0.9513, Accuracy: 0.5823, F1 Score: 0.5926, Precision: 0.6154, Recall: 0.5714, ROC AUC: 0.6319
# Epoch [10/50], Loss: 0.5024
# Validation Loss: 1.0046, Accuracy: 0.4810, F1 Score: 0.4810, Precision: 0.5135, Recall: 0.4524, ROC AUC: 0.5116
# Epoch [11/50], Loss: 0.4916
# Validation Loss: 0.9595, Accuracy: 0.5063, F1 Score: 0.5618, Precision: 0.5319, Recall: 0.5952, ROC AUC: 0.5714
# Epoch [12/50], Loss: 0.4744
# Validation Loss: 0.9875, Accuracy: 0.5190, F1 Score: 0.5682, Precision: 0.5435, Recall: 0.5952, ROC AUC: 0.5817
# Epoch [13/50], Loss: 0.4373
# Validation Loss: 1.0020, Accuracy: 0.5443, F1 Score: 0.5000, Precision: 0.6000, Recall: 0.4286, ROC AUC: 0.6441
# Epoch [14/50], Loss: 0.4197
# Validation Loss: 1.1470, Accuracy: 0.6456, F1 Score: 0.6216, Precision: 0.7188, Recall: 0.5476, ROC AUC: 0.7104
# Epoch [15/50], Loss: 0.3831
# Validation Loss: 1.0692, Accuracy: 0.6203, F1 Score: 0.6341, Precision: 0.6500, Recall: 0.6190, ROC AUC: 0.7214
# Epoch [16/50], Loss: 0.3444
# Validation Loss: 1.2062, Accuracy: 0.6582, F1 Score: 0.6494, Precision: 0.7143, Recall: 0.5952, ROC AUC: 0.7471
# Epoch [17/50], Loss: 0.3236
# Validation Loss: 1.0346, Accuracy: 0.6962, F1 Score: 0.7273, Precision: 0.6957, Recall: 0.7619, ROC AUC: 0.7690
# Epoch [18/50], Loss: 0.3275
# Validation Loss: 1.0579, Accuracy: 0.7342, F1 Score: 0.7123, Precision: 0.8387, Recall: 0.6190, ROC AUC: 0.8115
# Epoch [19/50], Loss: 0.2994
# Validation Loss: 2.1777, Accuracy: 0.6329, F1 Score: 0.5397, Precision: 0.8095, Recall: 0.4048, ROC AUC: 0.7111
# Epoch [20/50], Loss: 0.3244
# Validation Loss: 1.2227, Accuracy: 0.7089, F1 Score: 0.7767, Precision: 0.6557, Recall: 0.9524, ROC AUC: 0.7664
# Epoch [21/50], Loss: 0.3503
# Validation Loss: 1.0763, Accuracy: 0.7342, F1 Score: 0.7640, Precision: 0.7234, Recall: 0.8095, ROC AUC: 0.7819
# Epoch [22/50], Loss: 0.2421
# Validation Loss: 0.8110, Accuracy: 0.7595, F1 Score: 0.7816, Precision: 0.7556, Recall: 0.8095, ROC AUC: 0.8591
# Epoch [23/50], Loss: 0.2318
# Validation Loss: 0.8226, Accuracy: 0.7848, F1 Score: 0.8211, Precision: 0.7358, Recall: 0.9286, ROC AUC: 0.8320
# Epoch [24/50], Loss: 0.2936
# Validation Loss: 0.9598, Accuracy: 0.7848, F1 Score: 0.7952, Precision: 0.8049, Recall: 0.7857, ROC AUC: 0.8462
# Epoch [25/50], Loss: 0.2047
# Validation Loss: 0.9307, Accuracy: 0.7848, F1 Score: 0.7901, Precision: 0.8205, Recall: 0.7619, ROC AUC: 0.8835
# Epoch [26/50], Loss: 0.1961
# Validation Loss: 0.8483, Accuracy: 0.8354, F1 Score: 0.8267, Precision: 0.9394, Recall: 0.7381, ROC AUC: 0.9093
# Epoch [27/50], Loss: 0.1882
# Validation Loss: 1.3657, Accuracy: 0.7215, F1 Score: 0.7179, Precision: 0.7778, Recall: 0.6667, ROC AUC: 0.8449
# Epoch [28/50], Loss: 0.1726
# Validation Loss: 1.4145, Accuracy: 0.7975, F1 Score: 0.7714, Precision: 0.9643, Recall: 0.6429, ROC AUC: 0.8816
# Epoch [29/50], Loss: 0.1770
# Validation Loss: 1.3949, Accuracy: 0.6582, F1 Score: 0.7033, Precision: 0.6531, Recall: 0.7619, ROC AUC: 0.7838
# Epoch [30/50], Loss: 0.1507
# Validation Loss: 1.7257, Accuracy: 0.7342, F1 Score: 0.7042, Precision: 0.8621, Recall: 0.5952, ROC AUC: 0.8610
# Epoch [31/50], Loss: 0.1849
# Validation Loss: 1.1435, Accuracy: 0.8228, F1 Score: 0.8333, Precision: 0.8333, Recall: 0.8333, ROC AUC: 0.9009
# Epoch [32/50], Loss: 0.2356
# Validation Loss: 1.6072, Accuracy: 0.7215, F1 Score: 0.6765, Precision: 0.8846, Recall: 0.5476, ROC AUC: 0.8964
# Epoch [33/50], Loss: 0.1647
# Validation Loss: 0.8198, Accuracy: 0.7848, F1 Score: 0.7952, Precision: 0.8049, Recall: 0.7857, ROC AUC: 0.9054
# Epoch [34/50], Loss: 0.1421
# Validation Loss: 1.2247, Accuracy: 0.7595, F1 Score: 0.8000, Precision: 0.7170, Recall: 0.9048, ROC AUC: 0.8443
# Epoch [35/50], Loss: 0.1287
# Validation Loss: 0.7201, Accuracy: 0.8354, F1 Score: 0.8471, Precision: 0.8372, Recall: 0.8571, ROC AUC: 0.9279
# Epoch [36/50], Loss: 0.0885
# Validation Loss: 1.4179, Accuracy: 0.8228, F1 Score: 0.8108, Precision: 0.9375, Recall: 0.7143, ROC AUC: 0.9170
# Epoch [37/50], Loss: 0.1057
# Validation Loss: 1.4655, Accuracy: 0.8228, F1 Score: 0.8108, Precision: 0.9375, Recall: 0.7143, ROC AUC: 0.8752
# Epoch [38/50], Loss: 0.0784
# Validation Loss: 1.0474, Accuracy: 0.8734, F1 Score: 0.8750, Precision: 0.9211, Recall: 0.8333, ROC AUC: 0.9324
# Epoch [39/50], Loss: 0.1031
# Validation Loss: 1.0785, Accuracy: 0.8354, F1 Score: 0.8267, Precision: 0.9394, Recall: 0.7381, ROC AUC: 0.9054
# Epoch [40/50], Loss: 0.1031
# Validation Loss: 1.4675, Accuracy: 0.8101, F1 Score: 0.8148, Precision: 0.8462, Recall: 0.7857, ROC AUC: 0.8919
# Epoch [41/50], Loss: 0.0961
# Validation Loss: 0.9129, Accuracy: 0.8608, F1 Score: 0.8608, Precision: 0.9189, Recall: 0.8095, ROC AUC: 0.9208
# Epoch [42/50], Loss: 0.0985
# Validation Loss: 0.8977, Accuracy: 0.8481, F1 Score: 0.8571, Precision: 0.8571, Recall: 0.8571, ROC AUC: 0.9189
# Epoch [43/50], Loss: 0.1280
# Validation Loss: 1.2866, Accuracy: 0.7468, F1 Score: 0.7368, Precision: 0.8235, Recall: 0.6667, ROC AUC: 0.8584
# Early stopping triggered.
# Average Validation Accuracy: 0.8488
# Average F1 Score: 0.8498
# Average Precision: 0.8500
# Average Recall: 0.8516
# Average ROC AUC: 0.9076

# %%
val_accuracies
# Out:
# [0.9125, 0.8125, 0.8227848101265823, 0.8227848101265823, 0.8734177215189873]

# %%
roc_aucs
# Out:
# [0.9245524296675192,
#  0.868042526579112,
#  0.9111969111969112,
#  0.9017971758664955,
#  0.9324324324324322]
