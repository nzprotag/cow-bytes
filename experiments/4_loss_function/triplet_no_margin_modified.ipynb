# %%
import os
import random
from PIL import Image
import torch
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision import models
import torch.nn as nn
import torch.optim as optim
from triplet_utils import *
from utils import *
from torch.utils.data import random_split
from triplet_utils import train_and_evaluate_triplet

# 2. Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# 3. Create the dataset and dataloader
folder_path = '../../data/BiteCount/salient_poses/'   # Adjust this path
dataset = TripletDataset(folder_path, transform)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
import torch.nn.functional as F

# Custom Triplet Loss without margin
def triplet_loss_no_margin(anchor, positive, negative):
    # Calculate the pairwise distances
    pos_dist = F.pairwise_distance(anchor, positive)
    neg_dist = F.pairwise_distance(anchor, negative)
    
    # Compute the triplet loss without a margin
    loss = torch.clamp(pos_dist - neg_dist, min=0.0)
    
    # Return the mean of the loss over the batch
    return loss.mean()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)

# Function to show a batch of triplets
def show_triplet_images(dataloader, num_triplets=4):
    # Get a batch of data
    anchor_batch, positive_batch, negative_batch, _ = next(iter(dataloader))
    
    # Set up matplotlib subplots
    fig, axes = plt.subplots(num_triplets, 3, figsize=(10, 10))

    # Convert tensors to numpy arrays for visualization
    def convert_tensor_to_img(tensor):
        # Convert to numpy, [C, H, W] -> [H, W, C]
        image = tensor.numpy().transpose((1, 2, 0))  # Permute to [H, W, C]
        image = np.clip(image, 0, 1)  # Clip any out-of-bound values (if necessary)
        return image
    
    # Show num_triplets triplet images (anchor, positive, negative)
    for i in range(num_triplets):
        # No need to permute in the caller; it is done inside convert_tensor_to_img
        anchor_img = convert_tensor_to_img(anchor_batch[i])
        positive_img = convert_tensor_to_img(positive_batch[i])
        negative_img = convert_tensor_to_img(negative_batch[i])

        # Display anchor, positive, negative in a row
        axes[i, 0].imshow(anchor_img)
        axes[i, 0].set_title('Anchor')
        axes[i, 0].axis('off')

        axes[i, 1].imshow(positive_img)
        axes[i, 1].set_title('Positive')
        axes[i, 1].axis('off')

        axes[i, 2].imshow(negative_img)
        axes[i, 2].set_title('Negative')
        axes[i, 2].axis('off')

    # Adjust spacing between plots
    plt.tight_layout()
    plt.show()

# Example usage
show_triplet_images(dataloader, num_triplets=4)

# %%
def custom_collate(batch):
    # Unpack the batch
    anchors, positives, negatives, labels = zip(*batch)

    # Stack tensors to create batches
    anchors = torch.stack(anchors)
    positives = torch.stack(positives)
    negatives = torch.stack(negatives)

    # Convert labels to a tensor
    labels = torch.tensor(labels, dtype=torch.float32).unsqueeze(1)

    return anchors, positives, negatives, labels

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
import numpy as np

# TripletModel definition
class TripletModel(nn.Module):
    def __init__(self):
        super(TripletModel, self).__init__()
        self.base_model = models.resnet50(pretrained=True)
        self.base_model.fc = nn.Linear(self.base_model.fc.in_features, 128)  # Adjust output size for embedding

    def forward(self, x):
        # Get the embedding directly from the base model
        return self.base_model(x)  # Call the model with input x

class TripletClassifier(nn.Module):
    def __init__(self, triplet_head, output_size=1):
        super(TripletClassifier, self).__init__()
        self.triplet_head = triplet_head
        self.classifier = nn.Linear(self.triplet_head.base_model.fc.out_features, output_size)  # Binary classification (logits)

    def forward(self, x):
        embedding = self.triplet_head(x)  # Output of base model
        class_output = self.classifier(embedding)  # Output for classification
        return embedding, class_output
# Load data
data_dir = '../../data/BiteCount/salient_poses/'

# Define transformations for training set and validation set
train_transforms = transforms.Compose([
    transforms.Resize((224, 224)),  # Resizing to square input
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

val_transforms = transforms.Compose([
    transforms.Resize((224, 224)),  # Resizing to square input
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load dataset
train_dataset = TripletDataset(data_dir, transform=train_transforms)
dataset_size = len(train_dataset)
class_names = train_dataset.classes

# Cross-validation setup
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Hyperparameters
batch_size = 64
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
num_epochs = 50
patience = 5
alpha = 0.7

# Placeholder to store metrics across folds
val_accuracies = []
val_f1_scores = []
precisions = []
recalls = []
roc_aucs = []

# Perform 5-Fold Cross Validation
fold_idx = 1

np.random.seed(42)

for train_idx, val_idx in kf.split(np.arange(dataset_size)):
    print(f"Fold {fold_idx}")

    # Subset the data for training and validation
    train_subset = torch.utils.data.Subset(train_dataset, train_idx)
    val_subset = torch.utils.data.Subset(train_dataset, val_idx)

    # Create DataLoader for train and validation
    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, collate_fn=custom_collate)
    val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False, collate_fn=custom_collate)

    # Initialize TripletModel
    triplet_model = TripletModel()
    # triplet_model.load_state_dict(torch.load('./triplet_model.pth'))
    model = TripletClassifier(triplet_model)
    model = model.to(device)

    # Define loss functions and optimizer
    criterion_classification = nn.BCEWithLogitsLoss()  # Binary cross-entropy with logits for binary classification
    criterion_triplet = triplet_loss_no_margin 
    optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.8)

    # Training loop with early stopping
    best_val_accuracy = float('inf')
    best_val_f1 = 0

    patience_counter = 0

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for batch in train_loader:
            # Unpack the batch correctly
            anchor, positive, negative, labels = batch
            
            # Move the tensors to the appropriate device
            anchor = anchor.to(device)
            positive = positive.to(device)
            negative = negative.to(device)
            labels = labels.to(device)  # Ensure labels are tensors

            # Forward pass
            anchor_embedding, anchor_output = model(anchor)
            positive_embedding, positive_output = model(positive)
            negative_embedding, negative_output = model(negative)

            # Calculate losses
            classification_loss = criterion_classification(anchor_output, labels)
            triplet_loss = criterion_triplet(anchor_embedding, positive_embedding, negative_embedding)

            # Combine losses
            loss = alpha * classification_loss + (1-alpha) * triplet_loss
            running_loss += loss.item()

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        avg_loss = running_loss / len(train_loader)
        print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {avg_loss:.4f}")

        # Validation step
        model.eval()
        val_preds, val_labels = [], []
        val_loss = 0.0

        with torch.no_grad():
            for batch in val_loader:
                anchor, positive, negative, labels = batch
                
                anchor = anchor.to(device)
                positive = positive.to(device)
                negative = negative.to(device)
                labels = labels.to(device)

                anchor_embedding, anchor_output = model(anchor)
                positive_embedding, positive_output = model(positive)
                negative_embedding, negative_output = model(negative)

                # Compute validation loss
                classification_loss = criterion_classification(anchor_output, labels)
                triplet_loss = criterion_triplet(anchor_embedding, positive_embedding, negative_embedding)
                val_loss += (classification_loss + triplet_loss).item()

                val_preds.append(torch.sigmoid(anchor_output).cpu().numpy())
                val_labels.append(labels.cpu().numpy())

        avg_val_loss = val_loss / len(val_loader)
        val_preds = np.concatenate(val_preds)
        val_labels = np.concatenate(val_labels)

        # Calculate metrics
        val_acc = accuracy_score(val_labels, (val_preds > 0.5).astype(int))
        val_f1 = f1_score(val_labels, (val_preds > 0.5).astype(int))
        precision = precision_score(val_labels, (val_preds > 0.5).astype(int))
        recall = recall_score(val_labels, (val_preds > 0.5).astype(int))
        roc_auc = roc_auc_score(val_labels, val_preds)

        # Print validation metrics
        print(f"Validation Loss: {avg_val_loss:.4f}, Accuracy: {val_acc:.4f}, F1 Score: {val_f1:.4f}, "
              f"Precision: {precision:.4f}, Recall: {recall:.4f}, ROC AUC: {roc_auc:.4f}")

        # Early stopping logic
        if val_acc > best_val_accuracy or val_f1 > best_val_f1:
            best_val_loss = avg_val_loss
            best_val_accuracy = val_acc
            best_val_f1 = val_f1
            best_precision = precision
            best_recall = recall
            best_roc_auc = roc_auc
            patience_counter = 0
            # Save model state
            torch.save(model.state_dict(), f'tripet_{fold_idx}.pth')
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break

    # Store fold metrics
    val_accuracies.append(best_val_accuracy)
    val_f1_scores.append(best_val_f1)
    precisions.append(best_precision)
    recalls.append(best_recall)
    roc_aucs.append(best_roc_auc)

    fold_idx += 1

    

# Print out the results after cross-validation
print(f"Average Validation Accuracy: {np.mean(val_accuracies):.4f}")
print(f"Average F1 Score: {np.mean(val_f1_scores):.4f}")
print(f"Average Precision: {np.mean(precisions):.4f}")
print(f"Average Recall: {np.mean(recalls):.4f}")
print(f"Average ROC AUC: {np.mean(roc_aucs):.4f}")
# Out:
# Fold 1
# Epoch [1/50], Loss: 0.8809
# Validation Loss: 1.6970, Accuracy: 0.4375, F1 Score: 0.2623, Precision: 0.2963, Recall: 0.2353, ROC AUC: 0.4098
# Epoch [2/50], Loss: 0.7152
# Validation Loss: 1.3809, Accuracy: 0.4375, F1 Score: 0.5946, Precision: 0.4286, Recall: 0.9706, ROC AUC: 0.5134
# Epoch [3/50], Loss: 0.6517
# Validation Loss: 1.2096, Accuracy: 0.3875, F1 Score: 0.4842, Precision: 0.3770, Recall: 0.6765, ROC AUC: 0.3593
# Epoch [4/50], Loss: 0.6169
# Validation Loss: 1.0581, Accuracy: 0.3750, F1 Score: 0.3421, Precision: 0.3095, Recall: 0.3824, ROC AUC: 0.3440
# Epoch [5/50], Loss: 0.5935
# Validation Loss: 0.9798, Accuracy: 0.4250, F1 Score: 0.5965, Precision: 0.4250, Recall: 1.0000, ROC AUC: 0.4795
# Epoch [6/50], Loss: 0.5783
# Validation Loss: 1.0007, Accuracy: 0.4875, F1 Score: 0.5287, Precision: 0.4340, Recall: 0.6765, ROC AUC: 0.5134
# Epoch [7/50], Loss: 0.5647
# Validation Loss: 0.9552, Accuracy: 0.4250, F1 Score: 0.5741, Precision: 0.4189, Recall: 0.9118, ROC AUC: 0.5748
# Epoch [8/50], Loss: 0.5497
# Validation Loss: 0.9236, Accuracy: 0.5375, F1 Score: 0.5747, Precision: 0.4717, Recall: 0.7353, ROC AUC: 0.5754
# Epoch [9/50], Loss: 0.5278
# Validation Loss: 0.9220, Accuracy: 0.5875, F1 Score: 0.6292, Precision: 0.5091, Recall: 0.8235, ROC AUC: 0.6324
# Epoch [10/50], Loss: 0.5205
# Validation Loss: 0.8909, Accuracy: 0.5250, F1 Score: 0.6122, Precision: 0.4688, Recall: 0.8824, ROC AUC: 0.6707
# Epoch [11/50], Loss: 0.4979
# Validation Loss: 0.8394, Accuracy: 0.6500, F1 Score: 0.6744, Precision: 0.5577, Recall: 0.8529, ROC AUC: 0.7270
# Epoch [12/50], Loss: 0.4843
# Validation Loss: 0.8995, Accuracy: 0.6000, F1 Score: 0.6000, Precision: 0.5217, Recall: 0.7059, ROC AUC: 0.7155
# Epoch [13/50], Loss: 0.4721
# Validation Loss: 0.8356, Accuracy: 0.7500, F1 Score: 0.7436, Precision: 0.6591, Recall: 0.8529, ROC AUC: 0.7954
# Epoch [14/50], Loss: 0.4471
# Validation Loss: 0.7120, Accuracy: 0.7125, F1 Score: 0.7229, Precision: 0.6122, Recall: 0.8824, ROC AUC: 0.8171
# Epoch [15/50], Loss: 0.4098
# Validation Loss: 0.7957, Accuracy: 0.7000, F1 Score: 0.7073, Precision: 0.6042, Recall: 0.8529, ROC AUC: 0.7781
# Epoch [16/50], Loss: 0.4039
# Validation Loss: 0.8250, Accuracy: 0.6750, F1 Score: 0.6750, Precision: 0.5870, Recall: 0.7941, ROC AUC: 0.7705
# Epoch [17/50], Loss: 0.3732
# Validation Loss: 0.6916, Accuracy: 0.7250, F1 Score: 0.7105, Precision: 0.6429, Recall: 0.7941, ROC AUC: 0.8606
# Epoch [18/50], Loss: 0.3486
# Validation Loss: 0.8838, Accuracy: 0.6750, F1 Score: 0.6667, Precision: 0.5909, Recall: 0.7647, ROC AUC: 0.8529
# Early stopping triggered.
# Fold 2
# Epoch [1/50], Loss: 0.8861
# Validation Loss: 1.6557, Accuracy: 0.4625, F1 Score: 0.5981, Precision: 0.4706, Recall: 0.8205, ROC AUC: 0.4403
# Epoch [2/50], Loss: 0.7087
# Validation Loss: 1.3084, Accuracy: 0.4250, F1 Score: 0.2333, Precision: 0.3333, Recall: 0.1795, ROC AUC: 0.3990
# Epoch [3/50], Loss: 0.6496
# Validation Loss: 1.3201, Accuracy: 0.4750, F1 Score: 0.1250, Precision: 0.3333, Recall: 0.0769, ROC AUC: 0.3827
# Epoch [4/50], Loss: 0.6190
# Validation Loss: 1.1678, Accuracy: 0.4750, F1 Score: 0.5882, Precision: 0.4762, Recall: 0.7692, ROC AUC: 0.3508
# Epoch [5/50], Loss: 0.5925
# Validation Loss: 1.1199, Accuracy: 0.4500, F1 Score: 0.1852, Precision: 0.3333, Recall: 0.1282, ROC AUC: 0.3365
# Epoch [6/50], Loss: 0.5668
# Validation Loss: 1.0683, Accuracy: 0.5375, F1 Score: 0.6476, Precision: 0.5152, Recall: 0.8718, ROC AUC: 0.4522
# Epoch [7/50], Loss: 0.5577
# Validation Loss: 1.0124, Accuracy: 0.4250, F1 Score: 0.3030, Precision: 0.3704, Recall: 0.2564, ROC AUC: 0.4709
# Epoch [8/50], Loss: 0.5485
# Validation Loss: 1.0545, Accuracy: 0.5125, F1 Score: 0.3390, Precision: 0.5000, Recall: 0.2564, ROC AUC: 0.5766
# Epoch [9/50], Loss: 0.5314
# Validation Loss: 1.0801, Accuracy: 0.5125, F1 Score: 0.5517, Precision: 0.5000, Recall: 0.6154, ROC AUC: 0.4565
# Epoch [10/50], Loss: 0.5091
# Validation Loss: 1.0332, Accuracy: 0.5875, F1 Score: 0.4923, Precision: 0.6154, Recall: 0.4103, ROC AUC: 0.6141
# Epoch [11/50], Loss: 0.4980
# Validation Loss: 1.0568, Accuracy: 0.5375, F1 Score: 0.4127, Precision: 0.5417, Recall: 0.3333, ROC AUC: 0.5510
# Epoch [12/50], Loss: 0.4618
# Validation Loss: 0.8768, Accuracy: 0.6375, F1 Score: 0.6947, Precision: 0.5893, Recall: 0.8462, ROC AUC: 0.6923
# Epoch [13/50], Loss: 0.4589
# Validation Loss: 1.0744, Accuracy: 0.5500, F1 Score: 0.5814, Precision: 0.5319, Recall: 0.6410, ROC AUC: 0.6204
# Epoch [14/50], Loss: 0.4376
# Validation Loss: 0.9515, Accuracy: 0.6250, F1 Score: 0.6341, Precision: 0.6047, Recall: 0.6667, ROC AUC: 0.6942
# Epoch [15/50], Loss: 0.3970
# Validation Loss: 0.9365, Accuracy: 0.5875, F1 Score: 0.5926, Precision: 0.5714, Recall: 0.6154, ROC AUC: 0.6291
# Epoch [16/50], Loss: 0.3940
# Validation Loss: 0.9843, Accuracy: 0.6625, F1 Score: 0.6966, Precision: 0.6200, Recall: 0.7949, ROC AUC: 0.7830
# Epoch [17/50], Loss: 0.3827
# Validation Loss: 1.1506, Accuracy: 0.7250, F1 Score: 0.7179, Precision: 0.7179, Recall: 0.7179, ROC AUC: 0.7761
# Epoch [18/50], Loss: 0.3554
# Validation Loss: 0.7912, Accuracy: 0.7750, F1 Score: 0.7955, Precision: 0.7143, Recall: 0.8974, ROC AUC: 0.8399
# Epoch [19/50], Loss: 0.3035
# Validation Loss: 1.3547, Accuracy: 0.6375, F1 Score: 0.6027, Precision: 0.6471, Recall: 0.5641, ROC AUC: 0.7161
# Epoch [20/50], Loss: 0.2979
# Validation Loss: 0.9353, Accuracy: 0.7375, F1 Score: 0.7342, Precision: 0.7250, Recall: 0.7436, ROC AUC: 0.8193
# Epoch [21/50], Loss: 0.2806
# Validation Loss: 0.6576, Accuracy: 0.7125, F1 Score: 0.7629, Precision: 0.6379, Recall: 0.9487, ROC AUC: 0.8537
# Epoch [22/50], Loss: 0.2688
# Validation Loss: 1.5485, Accuracy: 0.6750, F1 Score: 0.5357, Precision: 0.8824, Recall: 0.3846, ROC AUC: 0.8230
# Epoch [23/50], Loss: 0.3173
# Validation Loss: 1.0619, Accuracy: 0.7000, F1 Score: 0.7391, Precision: 0.6415, Recall: 0.8718, ROC AUC: 0.7317
# Early stopping triggered.
# Fold 3
# Epoch [1/50], Loss: 0.8923
# Validation Loss: 1.7061, Accuracy: 0.4810, F1 Score: 0.3492, Precision: 0.5238, Recall: 0.2619, ROC AUC: 0.5077
# Epoch [2/50], Loss: 0.7138
# Validation Loss: 1.3408, Accuracy: 0.4557, F1 Score: 0.5474, Precision: 0.4906, Recall: 0.6190, ROC AUC: 0.3880
# Epoch [3/50], Loss: 0.6502
# Validation Loss: 1.1624, Accuracy: 0.4937, F1 Score: 0.2857, Precision: 0.5714, Recall: 0.1905, ROC AUC: 0.3983
# Epoch [4/50], Loss: 0.6022
# Validation Loss: 1.0539, Accuracy: 0.4304, F1 Score: 0.2857, Precision: 0.4286, Recall: 0.2143, ROC AUC: 0.4826
# Epoch [5/50], Loss: 0.6007
# Validation Loss: 1.0943, Accuracy: 0.4430, F1 Score: 0.4211, Precision: 0.4706, Recall: 0.3810, ROC AUC: 0.3681
# Epoch [6/50], Loss: 0.5737
# Validation Loss: 0.9957, Accuracy: 0.5316, F1 Score: 0.6476, Precision: 0.5397, Recall: 0.8095, ROC AUC: 0.4440
# Epoch [7/50], Loss: 0.5656
# Validation Loss: 1.0024, Accuracy: 0.4051, F1 Score: 0.3380, Precision: 0.4138, Recall: 0.2857, ROC AUC: 0.4151
# Epoch [8/50], Loss: 0.5532
# Validation Loss: 1.0160, Accuracy: 0.4557, F1 Score: 0.5743, Precision: 0.4915, Recall: 0.6905, ROC AUC: 0.3835
# Epoch [9/50], Loss: 0.5201
# Validation Loss: 0.9109, Accuracy: 0.4937, F1 Score: 0.3750, Precision: 0.5455, Recall: 0.2857, ROC AUC: 0.5676
# Epoch [10/50], Loss: 0.5359
# Validation Loss: 0.9719, Accuracy: 0.4937, F1 Score: 0.5455, Precision: 0.5217, Recall: 0.5714, ROC AUC: 0.5264
# Epoch [11/50], Loss: 0.5031
# Validation Loss: 0.8935, Accuracy: 0.5570, F1 Score: 0.6465, Precision: 0.5614, Recall: 0.7619, ROC AUC: 0.5849
# Epoch [12/50], Loss: 0.5019
# Validation Loss: 1.0122, Accuracy: 0.4937, F1 Score: 0.4118, Precision: 0.5385, Recall: 0.3333, ROC AUC: 0.5502
# Epoch [13/50], Loss: 0.4856
# Validation Loss: 1.0082, Accuracy: 0.6456, F1 Score: 0.6744, Precision: 0.6591, Recall: 0.6905, ROC AUC: 0.7111
# Epoch [14/50], Loss: 0.4667
# Validation Loss: 0.9038, Accuracy: 0.5949, F1 Score: 0.6190, Precision: 0.6190, Recall: 0.6190, ROC AUC: 0.6583
# Epoch [15/50], Loss: 0.4455
# Validation Loss: 0.8644, Accuracy: 0.6582, F1 Score: 0.7033, Precision: 0.6531, Recall: 0.7619, ROC AUC: 0.7259
# Epoch [16/50], Loss: 0.3956
# Validation Loss: 0.9772, Accuracy: 0.6203, F1 Score: 0.5946, Precision: 0.6875, Recall: 0.5238, ROC AUC: 0.6885
# Epoch [17/50], Loss: 0.3915
# Validation Loss: 1.1822, Accuracy: 0.6076, F1 Score: 0.6173, Precision: 0.6410, Recall: 0.5952, ROC AUC: 0.7162
# Epoch [18/50], Loss: 0.3588
# Validation Loss: 1.0981, Accuracy: 0.6709, F1 Score: 0.7292, Precision: 0.6481, Recall: 0.8333, ROC AUC: 0.7529
# Epoch [19/50], Loss: 0.3579
# Validation Loss: 1.0039, Accuracy: 0.7722, F1 Score: 0.7857, Precision: 0.7857, Recall: 0.7857, ROC AUC: 0.8385
# Epoch [20/50], Loss: 0.3469
# Validation Loss: 0.9053, Accuracy: 0.7215, F1 Score: 0.7556, Precision: 0.7083, Recall: 0.8095, ROC AUC: 0.8578
# Epoch [21/50], Loss: 0.2978
# Validation Loss: 0.9461, Accuracy: 0.7975, F1 Score: 0.7838, Precision: 0.9062, Recall: 0.6905, ROC AUC: 0.8456
# Epoch [22/50], Loss: 0.2693
# Validation Loss: 0.7834, Accuracy: 0.7848, F1 Score: 0.8090, Precision: 0.7660, Recall: 0.8571, ROC AUC: 0.8861
# Epoch [23/50], Loss: 0.2508
# Validation Loss: 0.9677, Accuracy: 0.7595, F1 Score: 0.7467, Precision: 0.8485, Recall: 0.6667, ROC AUC: 0.8726
# Epoch [24/50], Loss: 0.3143
# Validation Loss: 1.0689, Accuracy: 0.7595, F1 Score: 0.7654, Precision: 0.7949, Recall: 0.7381, ROC AUC: 0.8468
# Epoch [25/50], Loss: 0.2636
# Validation Loss: 1.2117, Accuracy: 0.8101, F1 Score: 0.8193, Precision: 0.8293, Recall: 0.8095, ROC AUC: 0.8784
# Epoch [26/50], Loss: 0.2162
# Validation Loss: 1.0081, Accuracy: 0.7722, F1 Score: 0.7857, Precision: 0.7857, Recall: 0.7857, ROC AUC: 0.8726
# Epoch [27/50], Loss: 0.1919
# Validation Loss: 0.8431, Accuracy: 0.7975, F1 Score: 0.8182, Precision: 0.7826, Recall: 0.8571, ROC AUC: 0.8790
# Epoch [28/50], Loss: 0.1649
# Validation Loss: 0.9494, Accuracy: 0.8101, F1 Score: 0.8052, Precision: 0.8857, Recall: 0.7381, ROC AUC: 0.8745
# Epoch [29/50], Loss: 0.2283
# Validation Loss: 0.7916, Accuracy: 0.8101, F1 Score: 0.8235, Precision: 0.8140, Recall: 0.8333, ROC AUC: 0.8983
# Epoch [30/50], Loss: 0.2136
# Validation Loss: 0.8427, Accuracy: 0.8481, F1 Score: 0.8537, Precision: 0.8750, Recall: 0.8333, ROC AUC: 0.9382
# Epoch [31/50], Loss: 0.2009
# Validation Loss: 0.8041, Accuracy: 0.8101, F1 Score: 0.8276, Precision: 0.8000, Recall: 0.8571, ROC AUC: 0.9093
# Epoch [32/50], Loss: 0.1821
# Validation Loss: 0.7558, Accuracy: 0.7848, F1 Score: 0.8000, Precision: 0.7907, Recall: 0.8095, ROC AUC: 0.9035
# Epoch [33/50], Loss: 0.2321
# Validation Loss: 0.9706, Accuracy: 0.8481, F1 Score: 0.8537, Precision: 0.8750, Recall: 0.8333, ROC AUC: 0.8745
# Epoch [34/50], Loss: 0.1622
# Validation Loss: 0.9722, Accuracy: 0.8354, F1 Score: 0.8354, Precision: 0.8919, Recall: 0.7857, ROC AUC: 0.8919
# Epoch [35/50], Loss: 0.1564
# Validation Loss: 1.1458, Accuracy: 0.8101, F1 Score: 0.8193, Precision: 0.8293, Recall: 0.8095, ROC AUC: 0.8700
# Early stopping triggered.
# Fold 4
# Epoch [1/50], Loss: 0.8650
# /home/sadat/miniconda3/envs/cs721/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Validation Loss: 1.7964, Accuracy: 0.4810, F1 Score: 0.0000, Precision: 0.0000, Recall: 0.0000, ROC AUC: 0.4596
# Epoch [2/50], Loss: 0.7107
# Validation Loss: 1.3546, Accuracy: 0.4684, F1 Score: 0.6316, Precision: 0.4932, Recall: 0.8780, ROC AUC: 0.3800
# Epoch [3/50], Loss: 0.6511
# Validation Loss: 1.3971, Accuracy: 0.3671, F1 Score: 0.4186, Precision: 0.4000, Recall: 0.4390, ROC AUC: 0.3209
# Epoch [4/50], Loss: 0.6035
# Validation Loss: 1.1979, Accuracy: 0.4051, F1 Score: 0.4051, Precision: 0.4211, Recall: 0.3902, ROC AUC: 0.3838
# Epoch [5/50], Loss: 0.5730
# Validation Loss: 1.0749, Accuracy: 0.4304, F1 Score: 0.0816, Precision: 0.2500, Recall: 0.0488, ROC AUC: 0.3935
# Epoch [6/50], Loss: 0.5692
# Validation Loss: 1.0758, Accuracy: 0.4051, F1 Score: 0.4835, Precision: 0.4400, Recall: 0.5366, ROC AUC: 0.4012
# Epoch [7/50], Loss: 0.5446
# Validation Loss: 1.0291, Accuracy: 0.3544, F1 Score: 0.3200, Precision: 0.3529, Recall: 0.2927, ROC AUC: 0.3678
# Early stopping triggered.
# Fold 5
# Epoch [1/50], Loss: 0.8748
# Validation Loss: 1.6722, Accuracy: 0.4557, F1 Score: 0.4557, Precision: 0.4865, Recall: 0.4286, ROC AUC: 0.4730
# Epoch [2/50], Loss: 0.7176
# Validation Loss: 1.2706, Accuracy: 0.4810, F1 Score: 0.6095, Precision: 0.5079, Recall: 0.7619, ROC AUC: 0.4974
# Epoch [3/50], Loss: 0.6493
# Validation Loss: 1.1619, Accuracy: 0.4304, F1 Score: 0.0000, Precision: 0.0000, Recall: 0.0000, ROC AUC: 0.3996
# Epoch [4/50], Loss: 0.6198
# Validation Loss: 1.0952, Accuracy: 0.4304, F1 Score: 0.3284, Precision: 0.4400, Recall: 0.2619, ROC AUC: 0.4311
# Epoch [5/50], Loss: 0.5852
# Validation Loss: 1.1563, Accuracy: 0.3924, F1 Score: 0.1429, Precision: 0.2857, Recall: 0.0952, ROC AUC: 0.3636
# Epoch [6/50], Loss: 0.5792
# Validation Loss: 0.9763, Accuracy: 0.4430, F1 Score: 0.5849, Precision: 0.4844, Recall: 0.7381, ROC AUC: 0.3526
# Epoch [7/50], Loss: 0.5555
# Validation Loss: 1.1162, Accuracy: 0.4810, F1 Score: 0.1633, Precision: 0.5714, Recall: 0.0952, ROC AUC: 0.3906
# Early stopping triggered.
# Average Validation Accuracy: 0.6645
# Average F1 Score: 0.7268
# Average Precision: 0.6499
# Average Recall: 0.8447
# Average ROC AUC: 0.6902

# %%
val_accuracies
# Out:
# [0.75, 0.775, 0.8481012658227848, 0.46835443037974683, 0.4810126582278481]

# %%
roc_aucs
# Out:
# [0.7953964194373401,
#  0.8398999374609131,
#  0.9382239382239381,
#  0.37997432605905,
#  0.4974259974259974]

# %% [markdown]
# lr=0.01, momentum=0.8;
